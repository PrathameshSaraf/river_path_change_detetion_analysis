# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\2019_f.jpg")


(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 1000
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)

# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])

# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)
# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("2019b.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\2021_F.png")


(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 1000
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)


# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)

# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("2021b.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\2015F.png")


(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 1000
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)

# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)

# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("2015b.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\2013_F.png")


(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)


# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 500
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)

# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)

# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("2013b.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\2017.png")


(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
plt.imshow(thresh)
# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 1000
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)


# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)


# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("2017b.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\2019_op.png")


(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

plt.imshow(thresh)
cv2.imwrite("2019_thresh_op.png",thresh)
# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 1000
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)


# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)


# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("2023b.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\1994_f.jpg")


(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 1000
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)

# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)

# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("1994b.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\1997_F.png")

(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 1000
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)
# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)

# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("1997b.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\2003.png")


(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 1000
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)

# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)

# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("2003b.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\2015F.png")


(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 1000
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)

# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)

# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("2015b.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
img = cv2.imread(r"D:\DOCS AND DATASETS\final\path_2_paper.png")


(h, w) = img.shape[:2]
img = cv2.resize(img, (w, h))
gry = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
thr = cv2.threshold(gry, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]


# Apply thresholding
_, thresh = cv2.threshold(thr, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Apply morphological operations to fill small gaps
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (5, 5))
morph = cv2.morphologyEx(thresh, cv2.MORPH_CLOSE, kernel)

# Find contours
contours, _ = cv2.findContours(morph, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Filter out contours that are too small
min_area = 1000
filtered_contours = [c for c in contours if cv2.contourArea(c) > min_area]

# Find the largest contour
largest_contour = max(filtered_contours, key=cv2.contourArea)

# Draw the largest contour on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)

# Calculate the length of the red region
length = cv2.arcLength(largest_contour, True)

# Calculate the area of the largest contour
area = cv2.contourArea(largest_contour)

# Calculate the perimeter of the largest contour
perimeter = cv2.arcLength(largest_contour, False)

# Calculate the centroid of the largest contour
M = cv2.moments(largest_contour)
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
# Draw the largest contour and centroid on the original image
cv2.drawContours(img, [largest_contour], -1, (0, 0, 255), 2)
cv2.circle(img, (cx, cy), 5, (255, 0, 0), -1)

# Convert the BGR image to RGB format
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2.imwrite("Path2_Paperb.png",img)
plt.imshow(img)
plt.axis('off')
plt.title('Length of Red Region: {:.2f} pixels\nArea of Red Region: {:.2f} pixels\nPerimeter of Red Region: {:.2f} pixels\nCentroid of Red Region: ({}, {})'.format(length, area, perimeter, cx, cy))
plt.show()
